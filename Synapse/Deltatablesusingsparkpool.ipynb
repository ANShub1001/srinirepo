-- %%
create database srinisparkdb ;

-- %%
CREATE TABLE srinisparkdb.Customer (
    CustomerID INT,
    Name string,
    Email string,
    Age INT
)
using csv

-- %%
INSERT INTO srinisparkdb.Customer (CustomerID, Name, Email, Age)
VALUES 
(1, 'John Doe', 'john@example.com', 30),
(2, 'Jane Smith', 'jane@example.com', 28);

-- %%
Describe extended srinisparkdb.Customer

-- %%
create table cdtc
(
id int,
name string

)
using csv 
OPTIONS (header 'TRUE')
Location 'abfss://demo@srinistracc.dfs.core.windows.net/sampleAZ.csv'

-- %%
select * from cdtc

-- %%
Describe extended cdtc

-- %%
select * from srinisparkdb.Customer

-- %%
CREATE TABLE srinisparkdb.Customerdelta (
    CustomerID INT,
    Name string,
    Email string,
    Age INT
)
using DELTA

-- %%
INSERT INTO srinisparkdb.Customerdelta (CustomerID, Name, Email, Age)
VALUES 
(1, 'ANS', 'ANS@example.com', 28),
(2, 'srini', 'srini@example.com', 29);

-- %%
update  srinisparkdb.Customer set name = 'ANS1' where CustomerID =2

-- %%
select * from srinisparkdb.Customer

-- %%
update  srinisparkdb.Customerdelta set name = 'ANS1' where CustomerID =2

-- %%
select * from srinisparkdb.Customerdelta

-- %%
Delete from srinisparkdb.Customerdelta where CustomerID =1

-- %%
select * from srinisparkdb.Customerdelta
